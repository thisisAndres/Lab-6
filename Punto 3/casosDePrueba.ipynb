# %% [markdown]
# ### Criterio de aceptación: Validación del formulario de registro
#
# #### ID del caso de prueba: CT-1.1
# **Descripción del caso:** Validar campo nombre vacío
#
# **Precondiciones:** El campo nombre está vacío.
#
# **Datos de entrada:**
# - Nombre: (vacío)
# - Correo electrónico: usuario@ejemplo.com
# - Contraseña: contraseña123
#
# **Pasos a seguir:**
# 1. Dejar el campo "Nombre" vacío.
# 2. Ingresar "usuario@ejemplo.com" en el campo "Correo electrónico".
# 3. Ingresar "contraseña123" en el campo "Contraseña".
# 4. Hacer clic en "Enviar".
#
# **Resultado esperado:**
# Mostrar mensaje de error "El campo nombre es obligatorio".
#
# **Resultado real:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
#
# **Estado:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
#
# ---
#
# #### ID del caso de prueba: CT-1.2
# **Descripción del caso:** Validar formato de correo electrónico incorrecto
#
# **Precondiciones:** El campo correo electrónico contiene "user@domain".
#
# **Datos de entrada:**
# - Nombre: Usuario Ejemplo
# - Correo electrónico: user@domain
# - Contraseña: contraseña123
#
# **Pasos a seguir:**
# 1. Ingresar "Usuario Ejemplo" en el campo "Nombre".
# 2. Ingresar "user@domain" en el campo "Correo electrónico".
# 3. Ingresar "contraseña123" en el campo "Contraseña".
# 4. Hacer clic en "Enviar".
#
# **Resultado esperado:**
# Mostrar mensaje de error "Formato de correo electrónico inválido".
#
# **Resultado real:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
#
# **Estado:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
#
# ---
#
# #### ID del caso de prueba: CT-1.3
# **Descripción del caso:** Validar contraseña mínima
#
# **Precondiciones:** El campo contraseña contiene "123".
#
# **Datos de entrada:**
# - Nombre: Usuario Ejemplo
# - Correo electrónico: usuario@ejemplo.com
# - Contraseña: 123
#
# **Pasos a seguir:**
# 1. Ingresar "Usuario Ejemplo" en el campo "Nombre".
# 2. Ingresar "usuario@ejemplo.com" en el campo "Correo electrónico".
# 3. Ingresar "123" en el campo "Contraseña".
# 4. Hacer clic en "Enviar".
#
# **Resultado esperado:**
# Mostrar mensaje de error "La contraseña debe tener al menos 6 caracteres".
#
# **Resultado real:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
#
# **Estado:**
# (N/A - Este campo se llena después de la ejecución de la prueba)
